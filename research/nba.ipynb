# %%
from nba_api.stats.endpoints import scheduleleaguev2

sched = scheduleleaguev2.ScheduleLeagueV2(league_id="00",season="2025-26")  # returns full league schedule payload
data = sched.get_dict()                       # or .get_json()

# %%
len(data['leagueSchedule']['gameDates']['gameDate'=='10/08/2023 00:00:00']['games'])
# Out:
# 1

# %%
data['leagueSchedule']['gameDates'][3]['games']
# Out:
# [{'gameId': '0012500029',
#   'gameCode': '20251005/OKCCHA',
#   'gameStatus': 1,
#   'gameStatusText': '5:00 pm ET',
#   'gameSequence': 2,
#   'gameDateEst': '2025-10-05T00:00:00Z',
#   'gameTimeEst': '1900-01-01T17:00:00Z',
#   'gameDateTimeEst': '2025-10-05T17:00:00Z',
#   'gameDateUTC': '2025-10-05T04:00:00Z',
#   'gameTimeUTC': '1900-01-01T21:00:00Z',
#   'gameDateTimeUTC': '2025-10-05T21:00:00Z',
#   'awayTeamTime': '2025-10-05T16:00:00Z',
#   'homeTeamTime': '2025-10-05T17:00:00Z',
#   'day': 'Sun',
#   'monthNum': 10,
#   'weekNumber': 0,
#   'weekName': '',
#   'ifNecessary': 'false',
#   'seriesGameNumber': '',
#   'gameLabel': 'Preseason',
#   'gameSubLabel': '',
#   'seriesText': '',
#   'arenaName': 'North Charleston Coliseum',
#   'arenaState': 'SC',
#   'arenaCity': 'Charleston',
#   'postponedStatus': 'N',
#   'branchLink': '',
#   'gameSubtype': '',
#   'isNeutral': False,
#   'broadcasters': {'nationalBroadcasters': [{'broadcasterScope': 'natl',
#      'broadcasterMedia': 'tv',
#      'broadcasterId': 1001042,
#      'broadcasterDisplay': 'TBD',
#      'broadcasterAbbreviation': 'TBD',
#      'broadcasterDescription': '',
#      'tapeDelayComments': '',
#      'broadcasterVideoLink': '',
#      'broadcasterTeamId': -1,
#      'broadcasterRanking': None,
#      'localizationRegion': ''}],
#    'nationalRadioBroadcasters': [],
#    'nationalOttBroadcasters': [],
#    'homeTvBroadcasters': [],
#    'homeRadioBroadcasters': [],
#    'homeOttBroadcasters': [],
#    'awayTvBroadcasters': [],
#    'awayRadioBroadcasters': [],
#    'awayOttBroadcasters': []},
#   'homeTeam': {'teamId': 1610612766,
#    'teamName': 'Hornets',
#    'teamCity': 'Charlotte',
#    'teamTricode': 'CHA',
#    'teamSlug': 'hornets',
#    'wins': 0,
#    'losses': 0,
#    'score': 0,
#    'seed': 0},
#   'awayTeam': {'teamId': 1610612760,
#    'teamName': 'Thunder',
#    'teamCity': 'Oklahoma City',
#    'teamTricode': 'OKC',
#    'teamSlug': 'thunder',
#    'wins': 0,
#    'losses': 0,
#    'score': 0,
#    'seed': 0},
#   'pointsLeaders': []},
#  {'gameId': '0012500030',
#   'gameCode': '20251005/LALGSW',
#   'gameStatus': 1,
#   'gameStatusText': '8:30 pm ET',
#   'gameSequence': 3,
#   'gameDateEst': '2025-10-05T00:00:00Z',
#   'gameTimeEst': '1900-01-01T20:30:00Z',
#   'gameDateTimeEst': '2025-10-05T20:30:00Z',
#   'gameDateUTC': '2025-10-05T04:00:00Z',
#   'gameTimeUTC': '1900-01-01T00:30:00Z',
#   'gameDateTimeUTC': '2025-10-06T00:30:00Z',
#   'awayTeamTime': '2025-10-05T17:30:00Z',
#   'homeTeamTime': '2025-10-05T17:30:00Z',
#   'day': 'Sun',
#   'monthNum': 10,
#   'weekNumber': 0,
#   'weekName': '',
#   'ifNecessary': 'false',
#   'seriesGameNumber': '',
#   'gameLabel': 'Preseason',
#   'gameSubLabel': '',
#   'seriesText': '',
#   'arenaName': 'Chase Center',
#   'arenaState': 'CA',
#   'arenaCity': 'San Francisco',
#   'postponedStatus': 'N',
#   'branchLink': '',
#   'gameSubtype': '',
#   'isNeutral': False,
#   'broadcasters': {'nationalBroadcasters': [{'broadcasterScope': 'natl',
#      'broadcasterMedia': 'tv',
#      'broadcasterId': 2,
#      'broadcasterDisplay': 'ESPN',
#      'broadcasterAbbreviation': 'ESPN',
#      'broadcasterDescription': '',
#      'tapeDelayComments': '',
#      'broadcasterVideoLink': 'https://www.espn.com/espnplus/player/_/id/13d26142-a618-4a5c-8032-e43994d3035e?ex_cid=nba',
#      'broadcasterTeamId': -1,
#      'broadcasterRanking': 2,
#      'localizationRegion': ''}],
#    'nationalRadioBroadcasters': [],
#    'nationalOttBroadcasters': [],
#    'homeTvBroadcasters': [],
#    'homeRadioBroadcasters': [],
#    'homeOttBroadcasters': [],
#    'awayTvBroadcasters': [],
#    'awayRadioBroadcasters': [],
#    'awayOttBroadcasters': []},
#   'homeTeam': {'teamId': 1610612744,
#    'teamName': 'Warriors',
#    'teamCity': 'Golden State',
#    'teamTricode': 'GSW',
#    'teamSlug': 'warriors',
#    'wins': 0,
#    'losses': 0,
#    'score': 0,
#    'seed': 0},
#   'awayTeam': {'teamId': 1610612747,
#    'teamName': 'Lakers',
#    'teamCity': 'Los Angeles',
#    'teamTricode': 'LAL',
#    'teamSlug': 'lakers',
#    'wins': 0,
#    'losses': 0,
#    'score': 0,
#    'seed': 0},
#   'pointsLeaders': []}]

# %%
import pandas as pd
players_df = pd.read_csv('/Users/mathewjimmytzimas/Documents/newMac/projects/NbaGamePrediction/data/validation/players.csv')
players_df['GAME_DATE'] = pd.to_datetime(players_df['GAME_DATE'])
players_df.head()
# Out:
#   SEASON_YEAR  PLAYER_ID     PLAYER_NAME  NICKNAME     TEAM_ID  \
# 0     2018-19     203110  Draymond Green  Draymond  1610612744
# 1     2018-19     200768      Kyle Lowry      Kyle  1610612761
# 2     2018-19    1627783   Pascal Siakam    Pascal  1610612761
# 3     2018-19     202691   Klay Thompson      Klay  1610612744
# 4     2018-19     201939   Stephen Curry   Stephen  1610612744
#
#   TEAM_ABBREVIATION              TEAM_NAME   GAME_ID  GAME_DATE      MATCHUP  \
# 0               GSW  Golden State Warriors  41800406 2019-06-13  GSW vs. TOR
# 1               TOR        Toronto Raptors  41800406 2019-06-13    TOR @ GSW
# 2               TOR        Toronto Raptors  41800406 2019-06-13    TOR @ GSW
# 3               GSW  Golden State Warriors  41800406 2019-06-13  GSW vs. TOR
# 4               GSW  Golden State Warriors  41800406 2019-06-13  GSW vs. TOR
#
#    ... PFD_RANK  PTS_RANK  PLUS_MINUS_RANK  NBA_FANTASY_PTS_RANK  DD2_RANK  \
# 0  ...     5648     11293            13997                   357         1
# 1  ...     3383      1427             2304                   659         1
# 2  ...     9220      1427            11759                  1699         1
# 3  ...     2031       728             8748                  3112      2586
# 4  ...     3383      3079            15294                  2788      2586
#
#    TD3_RANK  WNBA_FANTASY_PTS_RANK  AVAILABLE_FLAG  MIN_SEC  TEAM_COUNT
# 0         1                    531             1.0    44:12           1
# 1       144                    609             1.0    41:42           1
# 2       144                   1345             1.0    46:10           1
# 3       144                   1894             1.0    31:60           1
# 4       144                   2523             1.0    41:53           1
#
# [5 rows x 70 columns]

# %%
games_df = pd.read_csv('/Users/mathewjimmytzimas/Documents/newMac/projects/NbaGamePrediction/data/validation/games.csv')
games_df.tail()
# Out:
#       SEASON_YEAR     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME  \
# 16079     2023-24  1610612750               MIN  Minnesota Timberwolves
# 16080     2023-24  1610612742               DAL        Dallas Mavericks
# 16081     2023-24  1610612747               LAL      Los Angeles Lakers
# 16082     2023-24  1610612750               MIN  Minnesota Timberwolves
# 16083     2023-24  1610612742               DAL        Dallas Mavericks
#
#         GAME_ID            GAME_DATE      MATCHUP WL        MIN  FGM  ...  \
# 16079  12300002  2023-10-07T00:00:00    MIN @ DAL  W  48.000000   39  ...
# 16080  12300002  2023-10-07T00:00:00  DAL vs. MIN  L  48.000000   35  ...
# 16081  12300003  2023-10-07T00:00:00    LAL @ GSW  L  41.433333   34  ...
# 16082  12300001  2023-10-05T00:00:00  MIN vs. DAL  W  48.000000   42  ...
# 16083  12300001  2023-10-05T00:00:00    DAL @ MIN  L  48.000000   34  ...
#
#        AST_RANK  TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  \
# 16079      1550      2592       654       302       1647     2282      2192
# 16080      2560      2736       972       784       2285      415       366
# 16081      2647      1366       972      1149       2012      415      1719
# 16082       920      2161      1331        18       2285     1609       160
# 16083      2647      1106       248       302       2755     2552       923
#
#        PTS_RANK  PLUS_MINUS_RANK  AVAILABLE_FLAG
# 16079      2108              813             1.0
# 16080      2532             1902             1.0
# 16081      2706             2244             1.0
# 16082      1543              552             1.0
# 16083      2410             2176             1.0
#
# [5 rows x 57 columns]

# %%
from nba_api.stats.static import players, teams
def home_away_id(games_df, game_id):
    """"
    Returns the home and away team IDs based on the game matchup string.

    Parameters:
    - games_df (pd.DataFrame): DataFrame containing game details with a 'MATCHUP' column.
    - game_id (int or str): The unique GAME_ID to find the matchup.

    Returns:
    - tuple: (home_team_id, away_team_id)
    """
    df_teams = pd.DataFrame(teams.get_teams())
    mat = games_df[games_df['GAME_ID']==game_id]['MATCHUP'].iloc[0]
    if '@' in mat:
        teams_abb = mat.split(' @ ')
        home_team_id = df_teams[df_teams['abbreviation']==teams_abb[1]]['id'].item()
        away_team_id = df_teams[df_teams['abbreviation']==teams_abb[0]]['id'].item()
    else : 
        teams_abb = mat.split('vs.')
        home_team_id = df_teams[df_teams['abbreviation']==teams_abb[0]]['id'].item()
        away_team_id = df_teams[df_teams['abbreviation']==teams_abb[1]]['id'].item()

    return home_team_id, away_team_id

# %%
def game_roster(players_log_df, games_df, game_id, keep_player_stats):

    # get home/away team IDs
    home_id, away_id = home_away_id(games_df, game_id)
    training_cols = ["PLAYER_ID", "TEAM_ID", "GAME_ID"] + keep_player_stats

    # players in this game
    game_players_stats = players_log_df[players_log_df["GAME_ID"] == game_id]
    home_players_game_stats = game_players_stats[game_players_stats["TEAM_ID"] == home_id][training_cols].copy()
    away_players_game_stats = game_players_stats[game_players_stats["TEAM_ID"] == away_id][training_cols].copy()

    # date of this game
    game_date = games_df.loc[games_df["GAME_ID"] == game_id, "GAME_DATE"].iloc[0]

    # season stats before this game
    mask = (
        (players_log_df["GAME_DATE"] < game_date)
        & (players_log_df["TEAM_ID"].isin([home_id, away_id]))
    )
    season_df = players_log_df.loc[mask, training_cols]

    players_season_stats = (
        season_df
        .groupby(["PLAYER_ID", "TEAM_ID"], as_index=False)[keep_player_stats]
        .mean()
    )

    # match only players who appeared in this specific game
    home_players_season_stats = players_season_stats[
        players_season_stats["PLAYER_ID"].isin(home_players_game_stats["PLAYER_ID"])
    ].copy()
    away_players_season_stats = players_season_stats[
        players_season_stats["PLAYER_ID"].isin(away_players_game_stats["PLAYER_ID"])
    ].copy()

    home_players_game_stats['HOME_ID'] =  away_players_game_stats['HOME_ID'] = home_players_season_stats['HOME_ID'] = away_players_season_stats['HOME_ID'] = \
        home_id
    
    away_players_game_stats['AWAY_ID'] =  home_players_game_stats['AWAY_ID'] = away_players_season_stats['AWAY_ID'] = home_players_season_stats['AWAY_ID'] = \
        away_id
        
    return (
        home_players_game_stats,
        away_players_game_stats,
        home_players_season_stats,
        away_players_season_stats,
    )

# %%
keep_player_stats = ['MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM',
       'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL', 'BLK',
       'BLKA', 'PF', 'PFD', 'PTS', 'PLUS_MINUS']

# %%
game_roster(players_log_df=players_df, games_df=games_df, game_id=41800406,keep_player_stats=keep_player_stats)[1].tail(20)
# Out:
#     PLAYER_ID     TEAM_ID   GAME_ID        MIN  FGM  FGA  FG_PCT  FG3M  FG3A  \
# 1      200768  1610612761  41800406  41.700000    9   16   0.563     4     7
# 2     1627783  1610612761  41800406  46.166667   10   17   0.588     3     6
# 5      202695  1610612761  41800406  41.083333    7   16   0.438     1     5
# 7     1627832  1610612761  41800406  33.800000    6   14   0.429     5    11
# 9      201586  1610612761  41800406  22.118333    7   12   0.583     0     1
# 11     201188  1610612761  41800406  26.566667    0    5   0.000     0     2
# 13     201980  1610612761  41800406  17.726667    0    0   0.000     0     0
# 17    1626181  1610612761  41800406  10.838333    0    2   0.000     0     1
#
#     FG3_PCT  ...  TOV  STL  BLK  BLKA  PF  PFD  PTS  PLUS_MINUS     HOME_ID  \
# 1     0.571  ...    3    3    0     1   5    4   26          16  1610612744
# 2     0.500  ...    2    1    1     0   2    2   26           2  1610612744
# 5     0.200  ...    2    2    1     0   4    6   22          -2  1610612744
# 7     0.455  ...    1    1    0     1   1    6   22         -10  1610612744
# 9     0.000  ...    1    0    0     2   4    1   15           9  1610612744
# 11    0.000  ...    1    0    0     1   4    4    3          -7  1610612744
# 13    0.000  ...    1    1    0     0   1    0    0           7  1610612744
# 17    0.000  ...    1    0    0     1   2    0    0           5  1610612744
#
#        AWAY_ID
# 1   1610612761
# 2   1610612761
# 5   1610612761
# 7   1610612761
# 9   1610612761
# 11  1610612761
# 13  1610612761
# 17  1610612761
#
# [8 rows x 27 columns]

# %%
games_df.keys()
# Out:
# Index(['SEASON_YEAR', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID',
#        'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M',
#        'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST',
#        'TOV', 'STL', 'BLK', 'BLKA', 'PF', 'PFD', 'PTS', 'PLUS_MINUS',
#        'GP_RANK', 'W_RANK', 'L_RANK', 'W_PCT_RANK', 'MIN_RANK', 'FGM_RANK',
#        'FGA_RANK', 'FG_PCT_RANK', 'FG3M_RANK', 'FG3A_RANK', 'FG3_PCT_RANK',
#        'FTM_RANK', 'FTA_RANK', 'FT_PCT_RANK', 'OREB_RANK', 'DREB_RANK',
#        'REB_RANK', 'AST_RANK', 'TOV_RANK', 'STL_RANK', 'BLK_RANK', 'BLKA_RANK',
#        'PF_RANK', 'PFD_RANK', 'PTS_RANK', 'PLUS_MINUS_RANK', 'AVAILABLE_FLAG'],
#       dtype='object')

# %%
def game_roster(players_log_df, games_df, game_id, keep_player_stats):

    # get home/away team IDs
    home_id, away_id = home_away_id(games_df, game_id)
    training_cols = ["PLAYER_ID", "TEAM_ID", "GAME_ID","SEASON_YEAR"] + keep_player_stats

    # players in this game
    game_players_stats = players_log_df[players_log_df["GAME_ID"] == game_id]
    home_players_game_stats = game_players_stats[game_players_stats["TEAM_ID"] == home_id][training_cols].copy()
    away_players_game_stats = game_players_stats[game_players_stats["TEAM_ID"] == away_id][training_cols].copy()

    # date of this game
    game_date = games_df.loc[games_df["GAME_ID"] == game_id, "GAME_DATE"].iloc[0]

    # season stats before this game
    mask = (
        (players_log_df["GAME_DATE"] < game_date)
        & (players_log_df["TEAM_ID"].isin([home_id, away_id]))
    )
    season_df = players_log_df.loc[mask, training_cols]

    players_season_stats = (
        season_df
        .groupby(["PLAYER_ID", "TEAM_ID"], as_index=False)[keep_player_stats]
        .mean()
    )

    # match only players who appeared in this specific game
    home_players_season_stats = players_season_stats[
        players_season_stats["PLAYER_ID"].isin(home_players_game_stats["PLAYER_ID"])
    ].copy()
    away_players_season_stats = players_season_stats[
        players_season_stats["PLAYER_ID"].isin(away_players_game_stats["PLAYER_ID"])
    ].copy()

    home_players_game_stats['HOME_ID'] =  away_players_game_stats['HOME_ID'] = home_players_season_stats['HOME_ID'] = away_players_season_stats['HOME_ID'] = \
        home_id
    
    away_players_game_stats['AWAY_ID'] =  home_players_game_stats['AWAY_ID'] = away_players_season_stats['AWAY_ID'] = home_players_season_stats['AWAY_ID'] = \
        away_id
        
    return (
        home_players_game_stats,
        away_players_game_stats,
        home_players_season_stats,
        away_players_season_stats,
    )

# %%
def get_players_game_stats(players_log_df, games_df, game_id, keep_player_stats):
    # get home/away team IDs
    home_id, away_id = home_away_id(games_df, game_id)
    training_cols = ["PLAYER_ID", "TEAM_ID", "GAME_ID"] + keep_player_stats

    # players in this game
    game_players_stats = players_log_df[players_log_df["GAME_ID"] == game_id]
    home_players_game_stats = game_players_stats[game_players_stats["TEAM_ID"] == home_id][training_cols].copy()
    away_players_game_stats = game_players_stats[game_players_stats["TEAM_ID"] == away_id][training_cols].copy()

    home_players_game_stats['HOME_ID'] =  away_players_game_stats['HOME_ID'] = home_id
    
    away_players_game_stats['AWAY_ID'] =  home_players_game_stats['AWAY_ID'] = away_id

    return home_players_game_stats, away_players_game_stats

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined
