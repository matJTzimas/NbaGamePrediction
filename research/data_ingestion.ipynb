# %%
a=2

# %%
from nba_api.stats.endpoints import TeamGameLogs ,playergamelogs

playergamelogs23 = playergamelogs.PlayerGameLogs(season_nullable='2018-19',league_id_nullable='00')
playergamelogs23_df = playergamelogs23.get_data_frames()[0]
playergamelogs23_df.head()
# Out:
#   SEASON_YEAR  PLAYER_ID     PLAYER_NAME  NICKNAME     TEAM_ID  \
# 0     2018-19     203110  Draymond Green  Draymond  1610612744
# 1     2018-19     200768      Kyle Lowry      Kyle  1610612761
# 2     2018-19    1627783   Pascal Siakam    Pascal  1610612761
# 3     2018-19     202691   Klay Thompson      Klay  1610612744
# 4     2018-19     201939   Stephen Curry   Stephen  1610612744
#
#   TEAM_ABBREVIATION              TEAM_NAME     GAME_ID            GAME_DATE  \
# 0               GSW  Golden State Warriors  0041800406  2019-06-13T00:00:00
# 1               TOR        Toronto Raptors  0041800406  2019-06-13T00:00:00
# 2               TOR        Toronto Raptors  0041800406  2019-06-13T00:00:00
# 3               GSW  Golden State Warriors  0041800406  2019-06-13T00:00:00
# 4               GSW  Golden State Warriors  0041800406  2019-06-13T00:00:00
#
#        MATCHUP  ... PFD_RANK  PTS_RANK  PLUS_MINUS_RANK  NBA_FANTASY_PTS_RANK  \
# 0  GSW vs. TOR  ...     5648     11293            13997                   357
# 1    TOR @ GSW  ...     3383      1427             2304                   659
# 2    TOR @ GSW  ...     9220      1427            11759                  1699
# 3  GSW vs. TOR  ...     2031       728             8748                  3112
# 4  GSW vs. TOR  ...     3383      3079            15294                  2788
#
#    DD2_RANK  TD3_RANK  WNBA_FANTASY_PTS_RANK  AVAILABLE_FLAG  MIN_SEC  \
# 0         1         1                    531             1.0    44:12
# 1         1       144                    609             1.0    41:42
# 2         1       144                   1345             1.0    46:10
# 3      2586       144                   1894             1.0    31:60
# 4      2586       144                   2523             1.0    41:53
#
#    TEAM_COUNT
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
#
# [5 rows x 70 columns]
